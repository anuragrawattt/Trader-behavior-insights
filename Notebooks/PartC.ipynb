# %%
Strategy 1
- Insight: In your data, position sizes in USD shrink during Fear but token counts don’t always shrink proportionally.
- Rule of Thumb: On Fear days, scale positions by token count rather than USD value.
Most people will say “reduce leverage,” but I'm pointing out a subtle mismatch 
traders often cut USD exposure but still hold too many tokens. This rule forces discipline in both dimensions.

# %%
Strategy 2
- Insight: Long/Short bias shifts sharply with sentiment (longs dominate in Greed, shorts in Fear).
- Rule of Thumb: Cap the number of trades in the dominant bias direction once bias exceeds 70%.
Instead of just “trade more in Greed,”. Don’t let herd behavior push you into over‑concentration.
